# %%
import matplotlib.pyplot as plt

sizes = [2, 3]
colors = ['#a4c639', '#000000']

# create a pie chart
plt.pie(sizes, colors=colors,shadow=True,startangle=90)

# equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# display the chart
plt.show()
