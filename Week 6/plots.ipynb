# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv('Salaries.csv')

data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data['BasePay'].plot()
# Out:
# <AxesSubplot:>

# %%
# artist's record sales for the year

import numpy as np

artists=['Cardi B', 'Drake', 'Megan Thee Stallion', 'Lil Baby', 'Camailla Cabello']
sales=[150,300,650,400,950]
N=len(artists)
index = np.arange(N)
width=0.35

fig, ax = plt.subplots()

p = ax.bar(artists, sales, width, label="Artists")

ax.set_ylabel('Sales')
ax.set_title('Sales by Artist')
ax.axhline(0, color='grey', linewidth=0.8)


plt.show()
